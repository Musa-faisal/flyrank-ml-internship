# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Musa-faisal/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because the goal is to help prioritize which content pages should be reviewed first rather than simply predicting a label. This lane combines business decision-making with machine learning by producing a ranked review queue that helps content teams spend their limited time on the pages with the greatest potential opportunity. It also matches the starter dataset and provides a strong foundation for extending the project over the next several weeks.

# %%
# !git clone https://github.com/Musa-faisal/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# !pwd
# !ls

# My chosen lane
lane = "Refresh / Content Opportunity Scoring"

print("Chosen Lane:", lane)
print("Status: Provisional (can change until Week 4)")
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 123 (delta 38), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission
# Chosen Lane: Refresh / Content Opportunity Scoring
# Status: Provisional (can change until Week 4)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## Research Question
#
# **Decision**
#
# Which content pages should be reviewed first for refresh or improvement?
#
# **Action**
#
# Generate a ranked review queue so content managers can prioritize pages for refresh, expansion, monitoring, or further investigation.
#
# **Unit of Analysis**
#
# One content page.
#
# **Output**
#
# A ranked score representing each page's refresh opportunity along with supporting reason codes.
#
# **Cost of a Wrong Recommendation**
#
# If high-potential pages are missed, valuable traffic opportunities may be lost. If low-priority pages are recommended instead, teams may spend time reviewing pages that provide little business value. This project supports prioritization decisions but does not guarantee that refreshing a page will improve its performance.

# %%
decision = "Prioritize which content pages should be reviewed first."
unit_of_analysis = "One content page"
output = "Ranked refresh opportunity score"

print("Decision:", decision)
print("Unit of Analysis:", unit_of_analysis)
print("Output:", output)
# Out:
# Decision: Prioritize which content pages should be reviewed first.
# Unit of Analysis: One content page
# Output: Ranked refresh opportunity score

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This analysis is intended to support content review decisions rather than prove cause-and-effect relationships.
#
# The rankings identify pages that appear to deserve review based on observable search and engagement signals. They do not prove that refreshing a page will increase traffic or rankings.
#
# Any recommendations produced by this project should be reviewed by humans before implementation. All conclusions are observational and based only on the available anonymized dataset.

# %%
print("Dataset Shape:", df.shape)
print("Duplicate Pages:", df["content_id"].duplicated().sum())
# Out:
# Dataset Shape: (30000, 44)
# Duplicate Pages: 0

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
